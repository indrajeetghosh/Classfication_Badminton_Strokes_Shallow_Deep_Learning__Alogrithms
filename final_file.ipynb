# %%
fileNameWithPath = input('Enter file with path: ')
df = pd.ExcelFile(fileNameWithPath)
print(df.sheet_names)
z= df.parse('Sheet1')
print(z)
# Out:
# Enter file with path: Data annotation\RESEARCH WORK\Research_Work.xlsx
# ['Sheet1']
#                 ACTIVITY       DATE  CAMERA ACTUAL (START) ACTUAL(END)  \
# 0            WALKING - A 2021-06-01       1       02:47:28    02:47:34
# 1            WALKING - A 2021-06-01       1       02:48:10    02:48:13
# 2            WALKING - A 2021-06-01       1       02:48:28    02:48:34
# 3            WALKING - A 2021-06-01       1       03:04:38    03:05:11
# 4            WALKING - A 2021-06-01       1       04:09:05    04:09:11
# 5            WALKING - A 2021-06-01       1       04:11:51    04:11:58
# 6            WALKING - A 2021-06-01       1       04:12:43    04:12:49
# 7            WALKING - A 2021-06-01       1       04:14:21    04:14:27
# 8            WALKING - A 2021-06-01       1       04:14:58    04:15:05
# 9            WALKING - A 2021-06-01       1       04:55:41    04:55:53
# 10           WALKING - A 2021-06-01       1       04:57:21    04:57:26
# ...

# %%
import pandas as pd
fileNameWithPath = input('Enter file with path: ')
df = pd.ExcelFile(fileNameWithPath)
print(df.sheet_names)
z= df.parse('ACC')
print(z)
# Out:
# Enter file with path: E4_data\ACC.xlsx
# ['ACC']
#          1529604467  1529604467.1  1529604467.2
# 0                32            32            32
# 1               -19           -43           -39
# 2               -18           -37           -32
# 3               -33           -33           -46
# 4                -8           -50           -31
# 5                -3           -46           -42
# 6                -7           -48           -49
# 7               -12           -53           -47
# 8                -8           -47           -43
# 9                -2           -57           -56
# 10               -4           -59           -55
# 11              -24           -40           -54
# 12              -16           -40           -48
# 13              -16           -40           -50
# 14               -2           -62           -48
# 15              -19           -44           -43
# 16              -14           -37           -33
# ...

# %%
import pandas as pd
fileNameWithPath = input('Enter file with path: ')
df = pd.ExcelFile(fileNameWithPath)
print(df.sheet_names)
z= df.parse('BVP')
print(z)
# Out:
# Enter file with path: E4_data\BVP.xlsx
# ['BVP']
#          1529604467
# 0             64.00
# 1              0.00
# 2              0.00
# 3              0.00
# 4              0.00
# 5              0.00
# 6              0.00
# 7              0.00
# 8              0.00
# 9              0.00
# 10             0.00
# 11             0.00
# 12             0.01
# 13             0.01
# 14             0.00
# 15            -0.03
# 16            -0.05
# 17            -0.05
# 18             0.00
# 19             0.13
# 20             0.36
# 21             0.66
# 22             1.01
# 23             1.37
# 24             1.72
# 25             2.06
# 26             2.40
# 27             2.79
# 28             3.24
# 29             3.80
# ...             ...
# 1048545       -8.24
# 1048546       -0.30
# 1048547        1.66
# 1048548       -1.95
# 1048549      -10.79
# 1048550      -23.75
# 1048551      -39.27
# 1048552      -55.32
# 1048553      -70.05
# 1048554      -82.70
# 1048555      -93.37
# ...

# %%
import pandas as pd
fileNameWithPath = input('Enter file with path: ')
df = pd.ExcelFile(fileNameWithPath)
print(df.sheet_names)
z= df.parse('EDA')
print(z)
# Out:
# Enter file with path: E4_data\EDA.xlsx
# ['EDA']
#         1529604467
# 0         4.000000
# 1         0.000000
# 2         0.001281
# 3         0.023061
# 4         0.023061
# 5         0.024342
# 6         0.024342
# 7         0.025624
# 8         0.025624
# 9         0.026905
# 10        0.026905
# 11        0.026905
# 12        0.026905
# 13        0.026905
# 14        0.024342
# 15        0.025624
# 16        0.025624
# 17        0.025624
# 18        0.026905
# 19        0.025624
# 20        0.025624
# 21        0.025624
# 22        0.024342
# 23        0.024342
# 24        0.023061
# 25        0.023061
# 26        0.023061
# 27        0.021780
# 28        0.023061
# 29        0.023061
# ...            ...
# 361297    0.012812
# 361298    0.014093
# 361299    0.014093
# 361300    0.014093
# 361301    0.012812
# 361302    0.012812
# 361303    0.014093
# 361304    0.014093
# 361305    0.012812
# 361306    0.012812
# 361307    0.012812
# 361308    0.014093
# 361309    0.014093
# ...

# %%
import pandas as pd
fileNameWithPath = input('Enter file with path: ')
df = pd.ExcelFile(fileNameWithPath)
print(df.sheet_names)
z= df.parse('HR')
print(z)
# Out:
# Enter file with path: E4_data\HR.xlsx
# ['HR']
#        1529604477
# 0            1.00
# 1           74.00
# 2           62.50
# 3           59.00
# 4           64.00
# 5           66.40
# 6           65.33
# 7           64.57
# 8           64.00
# 9           63.56
# 10          63.20
# 11          62.55
# 12          61.58
# 13          60.69
# 14          60.43
# 15          60.27
# 16          60.19
# 17          60.18
# 18          60.17
# 19          60.47
# 20          60.50
# 21          60.57
# 22          60.82
# 23          60.96
# 24          61.33
# 25          61.68
# 26          62.08
# 27          62.22
# 28          62.57
# 29          62.90
# ...           ...
# 90294      109.95
# 90295      108.98
# 90296      109.87
# 90297      108.92
# 90298      109.17
# 90299      108.20
# 90300      108.97
# 90301      107.63
# 90302      109.33
# 90303      107.68
# 90304      108.82
# 90305      107.17
# 90306      108.95
# 90307      107.28
# 90308      108.32
# ...

# %%
import pandas as pd
fileNameWithPath = input('Enter file with path: ')
df = pd.ExcelFile(fileNameWithPath)
print(df.sheet_names)
z= df.parse('IBI')
print(z)
# Out:
# Enter file with path: E4_data\IBI.xlsx
# ['IBI']
#         1529604467       IBI
# 0       121.911830  0.984420
# 1       122.896250  0.984420
# 2       123.880670  0.984420
# 3       124.849465  0.968794
# 4       125.818259  0.968794
# 5       126.833930  1.015671
# 6       127.787099  0.953169
# 7       128.834022  1.046923
# 8       135.678085  0.968794
# 9       136.662505  0.984420
# 10      137.646925  0.984420
# 11      277.247065  0.828163
# 12     1317.154042  0.906291
# 13     1318.075959  0.921917
# 14     1318.997876  0.921917
# 15     1319.919793  0.921917
# 16     1333.873557  0.828163
# 17     1347.217918  0.812537
# 18     1348.264841  1.046923
# 19     2086.814273  0.812537
# 20     2087.642436  0.828163
# 21     2088.501850  0.859414
# 22     2117.112535  0.718783
# 23     2123.862844  0.843789
# 24     2137.347836  0.890666
# 25     2138.191625  0.843789
# 26     2139.097916  0.906291
# 27     2139.847950  0.750034
# 28     2149.035871  0.828163
# ...

# %%
import pandas as pd
fileNameWithPath = input('Enter file with path: ')
df = pd.ExcelFile(fileNameWithPath)
print(df.sheet_names)
z= df.parse('tags')
print(z)
# Out:
# Enter file with path: E4_data\tags.xlsx
# ['tags']
# Empty DataFrame
# Columns: [1529694802.57]
# Index: []

# %%
import pandas as pd
fileNameWithPath = input('Enter file with path: ')
df = pd.ExcelFile(fileNameWithPath)
print(df.sheet_names)
z= df.parse('TEMP')
print(z)
# Out:
# Enter file with path: E4_data\TEMP.xlsx
# ['TEMP']
#         1529604467
# 0             4.00
# 1            25.99
# 2            25.99
# 3            25.99
# 4            25.99
# 5            25.99
# 6            25.99
# 7            25.99
# 8            25.99
# 9            25.93
# 10           25.93
# 11           25.93
# 12           25.93
# 13           29.39
# 14           29.39
# 15           29.39
# 16           29.39
# 17           30.81
# 18           30.81
# 19           30.81
# 20           30.81
# 21           30.85
# 22           30.85
# 23           30.85
# 24           30.85
# 25           31.19
# 26           31.19
# 27           31.19
# 28           31.19
# 29           31.45
# ...            ...
# 361299       23.19
# 361300       23.19
# 361301       23.21
# 361302       23.21
# 361303       23.21
# 361304       23.21
# 361305       23.21
# 361306       23.21
# 361307       23.21
# 361308       23.21
# 361309       23.21
# 361310       23.21
# 361311       23.21
# ...

# %%
import pandas as pd
fileNameWithPath = input('Enter file with path: ')
df = pd.ExcelFile(fileNameWithPath)
print(df.sheet_names)
z= df.parse('Sheet1')
print(z)
# Out:
# Enter file with path: Data annotation\RESEARCH WORK\Research_Work.xlsx
# ['Sheet1']
#                 ACTIVITY       DATE  CAMERA ACTUAL (START) ACTUAL(END)  \
# 0            WALKING - A 2021-06-01       1       02:47:28    02:47:34
# 1            WALKING - A 2021-06-01       1       02:48:10    02:48:13
# 2            WALKING - A 2021-06-01       1       02:48:28    02:48:34
# 3            WALKING - A 2021-06-01       1       03:04:38    03:05:11
# 4            WALKING - A 2021-06-01       1       04:09:05    04:09:11
# 5            WALKING - A 2021-06-01       1       04:11:51    04:11:58
# 6            WALKING - A 2021-06-01       1       04:12:43    04:12:49
# 7            WALKING - A 2021-06-01       1       04:14:21    04:14:27
# 8            WALKING - A 2021-06-01       1       04:14:58    04:15:05
# 9            WALKING - A 2021-06-01       1       04:55:41    04:55:53
# 10           WALKING - A 2021-06-01       1       04:57:21    04:57:26
# ...

# %%
import pandas as pd
data = pd.read_csv("C:\Projects\Data annotation\RESEARCH WORK\Research Work.csv", low_memory=False)
print("Total rows: {0}".format(len(data)))
print(list(data))
# Out:
# Total rows: 76
# ['ACTIVITY\tDATE\tCAMERA\tACTUAL (START)\tACTUAL(END)\tTIMESTAMP']

# %%
import pandas as pd
df2=pd.read_csv("F:\Projects\Data annotation\RESEARCH WORK\Research_Work.csv")
print(df2)
# Out:
#                 ACTIVITY    DATE  CAMERA     START       END TIMESTAMP
# 0            WALKING - A  Jun-21       1   2:47:28   2:47:34   0:00:06
